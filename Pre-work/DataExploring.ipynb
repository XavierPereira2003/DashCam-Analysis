# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import imageio
import numpy as np
from glob import glob

image_paths = glob('idd20k_lite/leftImg8bit/train/*/*_image.jpg')
label_paths = [p.replace('leftImg8bit', 'gtFine').replace(
    '_image.jpg', '_label.png') for p in image_paths]

# Assigning some RGB colors for the 7 + 1 (Misc) classes
colors = np.array([
        [128, 64, 18],      # Drivable
        [244, 35, 232],     # Non Drivable
        [220, 20, 60],      # Living Things
        [0, 0, 230],        # Vehicles
        [220, 190, 40],     # Road Side Objects
        [70, 70, 70],       # Far Objects
        [70, 130, 180],     # Sky
        [0, 0, 0]           # Misc
    ], dtype=np.int32)

print(len(image_paths))

for i in range(len(image_paths)):
    print(image_paths[i], label_paths[i])
    image_frame = imageio.imread(image_paths[i])
    # print(image_frame.shape)
    label_map = imageio.imread(label_paths[i])
    color_image = np.zeros(
        (label_map.shape[0], label_map.shape[1], 3), dtype=np.int32)
    for i in range(7):
        color_image[label_map == i] = colors[i]

    color_image[label_map == 255] = colors[7]
    plt.imshow(image_frame)
    plt.imshow(color_image, alpha=0.8)
    plt.show()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
import imageio

image_paths = glob('idd20k_lite/Image/train/*/*_image.jpg')
label_paths = [p.replace('Image', 'label').replace(
    '_image.jpg', '_label.png') for p in image_paths]

# %%
image_paths[0], label_paths[0]
# Out:
# ('idd20k_lite/Image/train/548/0043118_image.jpg',
#  'idd20k_lite/label/train/548/0043118_label.png')

# %%
test_image= imageio.imread(image_paths[0])
test_label= imageio.imread(label_paths[0])
# Out:
# /tmp/ipykernel_83598/2926565856.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   test_image= imageio.imread(image_paths[0])
# /tmp/ipykernel_83598/2926565856.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   test_label= imageio.imread(label_paths[0])

# %%
test_label.shape
# Out:
# (227, 320)

# %%
test_label_np=np.array(test_label)

# %%
# Out:
# (array([0, 1, 2, 3, 4, 5, 6], dtype=uint8),
#  array([25357,  3514,  2070,  1100,  5175, 27827,  7597]))

# %%
test_image.shape
# Out:
# (227, 320, 3)

# %%
colors = np.array([
    [128, 64, 18],      # Drivable
    [244, 35, 232],     # Non Drivable
    [220, 20, 60],      # Living Things
    [0, 0, 230],        # Vehicles
    [220, 190, 40],     # Road Side Objects
    [70, 70, 70],       # Far Objects
    [70, 130, 180],     # Sky
    [0, 0, 0]           # Misc
], dtype=np.int32)

# %%
#print(image_paths[i], label_paths[i])
image_frame = imageio.imread(image_paths[0])
# print(image_frame.shape)
label_map = imageio.imread(label_paths[0])
color_image = np.zeros(
    (label_map.shape[0], label_map.shape[1], 3), dtype=np.int32)
#for i in range(7):
#    color_image[label_map == i] = colors[i]
color_image[label_map == 0] = colors[0]
#color_image[label_map == 255] = colors[7]
plt.imshow(image_frame)
plt.imshow(color_image, alpha=0.8)
plt.show()
# Out:
# /tmp/ipykernel_83598/402636923.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image_frame = imageio.imread(image_paths[0])
# /tmp/ipykernel_83598/402636923.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   label_map = imageio.imread(label_paths[0])

# %%
x_min, x_max=min(np.unique(test_label_np)), max(np.unique(test_label_np))
y_min, y_max=0, 255

scaled_label = (label_map - x_min) / (x_max - x_min) * (y_max - y_min) + y_min

plt.imshow(scaled_label, cmap='gray')
